# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# **Reading the data**

# %%
data=pd.read_csv("datafile.csv", header=None)

# %%
data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Exploratory Data Analysis**

# %%
data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.size
# Out:
# 750

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       150 non-null    float64
#  1   1       150 non-null    float64
#  2   2       150 non-null    float64
#  3   3       150 non-null    float64
#  4   4       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.isnull().sum()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
data.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
data0=data.rename(columns={0:"SepalLength"},inplace=True)
data1=data.rename(columns={1:"SepalWidth"},inplace=True)
data2=data.rename(columns={2:"PetalLength"},inplace=True)
data3=data.rename(columns={3:"PetalWidth"},inplace=True)
data4=data.rename(columns={4:"class"},inplace=True)

# %%
data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Data Visualization**

# %%
plt.hist(data['SepalLength'])
plt.show()

# %%
plt.hist(data['SepalWidth'])
plt.show()

# %%
plt.hist(data['PetalLength'])
plt.show()

# %%
plt.hist(data['PetalWidth'])
plt.show()

# %%
plt.plot(data['SepalLength'])
plt.plot(data['SepalWidth'])
plt.plot(data['PetalLength'])
plt.plot(data['PetalWidth'])
plt.show()

# %%
plt.hist(data['class'])
plt.show()

# %%
plt.boxplot(data['SepalLength'])
plt.show()

# %%
plt.boxplot(data['SepalWidth'])
plt.show()

# %%
plt.boxplot(data['PetalLength'])
plt.show()

# %%
plt.boxplot(data['PetalWidth'])
plt.show()

# %% [markdown]
# **Data Vistualization using Seaborn**

# %%
sns.scatterplot(data['SepalLength'])
sns.scatterplot(data['SepalWidth'])
sns.scatterplot(data['PetalLength'])
sns.scatterplot(data['PetalWidth'])
plt.show()

# %%
sns.pairplot(data)

# %%
sns.boxplot(x=data['class'],y=data['SepalLength'])
plt.show()

# %%
sns.boxplot(x=data['class'],y=data['SepalWidth'])
plt.show()

# %%
sns.boxplot(x=data['class'],y=data['PetalLength'])
plt.show()

# %%
sns.boxplot(x=data['class'],y=data['PetalWidth'])
plt.show()

# %%
sns.violinplot(x=data['class'],y=data['SepalLength'])
plt.show()

# %%
sns.violinplot(x=data['class'],y=data['SepalWidth'])
plt.show()

# %%
sns.violinplot(x=data['class'],y=data['PetalLength'])
plt.show()

# %%
sns.violinplot(x=data['class'],y=data['PetalWidth'])
# Out:
# <Axes: xlabel='class', ylabel='PetalWidth'>

# %%
sns.barplot(x=data['class'],y=data['SepalLength'])
# Out:
# <Axes: xlabel='class', ylabel='SepalLength'>

# %%
sns.barplot(x=data['class'],y=data['SepalWidth'])
# Out:
# <Axes: xlabel='class', ylabel='SepalWidth'>

# %%
sns.barplot(x=data['class'],y=data['PetalLength'])
# Out:
# <Axes: xlabel='class', ylabel='PetalLength'>

# %%
sns.barplot(x=data['class'],y=data['PetalWidth'])
# Out:
# <Axes: xlabel='class', ylabel='PetalWidth'>

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\LENOVO X1CARBON 5th\AppData\Local\Temp\ipykernel_1028\2578434383.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >
